# %%
import re
import ast
import pandas as pd
from pathlib import Path

SRC_DIR = Path('/Volumes/external_drive')

# %%
df = pd.read_csv('image_high_res.csv')
df = df[df['tags_list'].notnull()]
df = df[df['categories'].notnull()]

# %%
df['models'] = df['models'].apply(ast.literal_eval)
df['categories'] = df['categories'].apply(ast.literal_eval)
df['tags_list'] = df['tags_list'].apply(ast.literal_eval)

# %%
age_tags = [
    'Mature',
    'Granny',
    'MILF',
    'Cougar',
]
physical_look_tags = [
    'Chubby',
    'BBW',
    'Clothed',
    'Curvy',
    'Natural Tits',
    'Saggy Tits',
    'Thick',
]
utility_tags = [
    'Bath',
    'Beach',
    'Christmas',
    'Glasses',
    'Gym',
    'Masturbation',
    'Non Nude',
    'Nun',
    'Nurse',
    'Office',
    'Panties',
    'Dress',
    'Pantyhose',
    'Police',
    'Pool',
    'Secretary',
    'Uniform',
    'Upskirt',
    'Sports',
    'Stockings',
    'Undressing',
    'Amateur',
    'Homemade',
    'Housewife',
    'Solo',
    'Selfie',
    'Vintage'
]
negative_tags = [
    'AI',
    'Anal',
    'Anal Gape',
    'Ass Fucking',
    'Ass Licking',
    'BBC',
    'BDSM',
    'Babe',
    'Babysitter',
    'Ball Licking',
    'Ballerina',
    'Beautiful',
    'Big Clit',
    'Big Cock',
    'Bisexual',
    'Blindfold',
    'Blowbang',
    'Blowjob',
    'Bodysuit',
    'Bondage',
    'Braces',
    'Bukkake',
    'CFNM',
    'Casting',
    'Caught',
    'Cheating',
    'Cheerleader',
    'Close Up',
    'College',
    'Cosplay',
    'Couple',
    'Cowgirl',
    'Creampie',
    'Cuckold',
    'Cum In Mouth',
    'Cum In Pussy',
    'Cum Swapping',
    'Cumshot',
    'Deepthroat',
    'Dildo',
    'Doctor',
    'Doggy Style',
    'Double Penetration',
    'Emo',
    'Erotic',
    'FFM',
    'Facesitting',
    'Facial',
    'Family',
    'Femdom',
    'Fingering',
    'Fisting',
    'Footjob',
    'Gangbang',
    'Girlfriend',
    'Glamour',
    'Gloryhole',
    'Granny',
    'Groupsex',
    'Gyno',
    'Hairy',
    'Handjob',
    'Hardcore',
    'Hentai',
    'Humping',
    'Interracial',
    'Kissing',
    'Ladyboy',
    'Latex',
    'Leather',
    'Lesbian',
    'MMF',
    'Massage',
    'Missionary',
    'Model',
    'Old Man',
    'Old Young',
    'Orgasm',
    'Orgy',
    'Outdoor',
    'POV',
    'Party',
    'Pegging',
    'Piercing',
    'Pinay',
    'Pissing',
    'Pool',
    'Pornstar',
    'Pregnant',
    'Pretty',
    'Prison',
    'Pussy Licking',
    'Reality',
    'SS',
    'Sandals',
    'Schoolgirl',
    'Seduction',
    'Sex Doll',
    'Sexy',
    'Shemale',
    'Small Cock',
    'Spanking',
    'Squirting',
    'Step Brother',
    'Step Sister',
    'Stepmom',
    'Strapon',
    'Stripper',
    'Swingers',
    'Teen',
    'Thai',
    'Threesome',
    'Titjob',
    'Tribbing',
    'Twink',
    'Twins',
    'Underwater',
    'Voyeur',
    'Wedding',
    'Wet'
]

# %%
aged_df = df[df['categories'].apply(lambda x: any(category in age_tags for category in x))]
looks_df = aged_df[aged_df['categories'].apply(lambda x: any(category in physical_look_tags for category in x))]
utility_df = looks_df[looks_df['categories'].apply(lambda x: any(category in utility_tags for category in x))]
negative_aged_df = utility_df[
    utility_df['categories'].apply(lambda x: all(category not in negative_tags for category in x))]
negative_aged_df = negative_aged_df.reset_index(drop=True)

# %%
negative_aged_df.shape
# Out:
# (22426, 11)

# %%
negative_aged_df.head(20)
# Out:
#     category                                       gallery_name  \
# 0   non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 1   non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 2   non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 3   non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 4   non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 5   non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 6   non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 7   non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 8   non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 9   non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 10  non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 11  non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 12  non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 13  non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 14  non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 15  non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 16  non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 17  non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 18  non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 19  non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
#
#            channel     models  \
# 0   Only All Sites  [Luciana]
# 1   Only All Sites  [Luciana]
# 2   Only All Sites  [Luciana]
# 3   Only All Sites  [Luciana]
# 4   Only All Sites  [Luciana]
# 5   Only All Sites  [Luciana]
# 6   Only All Sites  [Luciana]
# 7   Only All Sites  [Luciana]
# 8   Only All Sites  [Luciana]
# 9   Only All Sites  [Luciana]
# 10  Only All Sites  [Luciana]
# 11  Only All Sites  [Luciana]
# 12  Only All Sites  [Luciana]
# 13  Only All Sites  [Luciana]
# 14  Only All Sites  [Luciana]
# 15  Only All Sites  [Luciana]
# 16  Only All Sites  [Luciana]
# 17  Only All Sites  [Luciana]
# 18  Only All Sites  [Luciana]
# 19  Only All Sites  [Luciana]
#
#                                            categories  \
# 0   [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 1   [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 2   [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 3   [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 4   [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 5   [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 6   [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 7   [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 8   [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 9   [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 10  [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 11  [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 12  [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 13  [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 14  [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 15  [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 16  [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 17  [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 18  [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 19  [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
#
#                                             tags_list rating   views  \
# 0   [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 1   [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 2   [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 3   [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 4   [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 5   [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 6   [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 7   [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 8   [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 9   [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 10  [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 11  [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 12  [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 13  [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 14  [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 15  [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 16  [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 17  [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 18  [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 19  [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
#
#                  filename  width  height
# 0   57352172_127_33ed.jpg   1280     853
# 1   57352172_022_99c3.jpg   1280     853
# 2   57352172_075_dc2a.jpg   1280     853
# 3   57352172_120_8cac.jpg   1280     853
# 4   57352172_080_1f1f.jpg   1280     853
# 5   57352172_084_07da.jpg   1280     853
# 6   57352172_094_183b.jpg   1280     853
# 7   57352172_067_b456.jpg    853    1280
# 8   57352172_096_bed1.jpg   1280     853
# 9   57352172_069_fb9c.jpg   1280     853
# 10  57352172_059_6378.jpg   1280     853
# 11  57352172_033_415b.jpg   1280     853
# 12  57352172_041_6331.jpg   1280     853
# 13  57352172_049_7dfe.jpg   1280     853
# 14  57352172_011_0d78.jpg   1280     853
# 15  57352172_019_fc9c.jpg   1280     853
# 16  57352172_106_e213.jpg   1280     853
# 17  57352172_115_118d.jpg   1280     853
# 18  57352172_056_95a5.jpg   1280     853
# 19  57352172_006_6ab0.jpg   1280     853

# %%
all_tags = sorted(list(set([item for sublist in negative_aged_df['categories'] for item in sublist])))


def clean_list(lst):
    lst = [re.sub(r'\s+', ' ', item) for item in lst]
    return list(set([item for item in lst if item != '']))


all_tags = clean_list(all_tags)
all_tags = sorted(list(clean_list(all_tags)))
all_tags
# Out:
# ['African',
#  'Amateur',
#  'Arab',
#  'Armpit',
#  'Asian',
#  'Ass',
#  'Asshole',
#  'Australian',
#  'BBW',
#  'Bath',
#  'Beach',
#  'Big Tits',
#  'Bikini',
#  'Blonde',
#  'Boots',
#  'Brazilian',
#  'British',
#  'Brunette',
#  'Cameltoe',
#  'Canadian',
#  'Centerfold',
#  'Christmas',
#  'Chubby',
#  'Clothed',
#  'Colombian',
#  'Cougar',
#  'Cuban',
#  'Curly',
#  'Curvy',
#  'Cute',
#  'Czech',
#  'Dress',
#  'Dutch',
#  'Ebony',
#  'European',
#  'Face',
#  'Fake Tits',
#  'Farm',
#  'Feet',
#  'Fetish',
#  'Flexible',
#  'French',
#  'German',
#  'Glasses',
#  'Gym',
#  'High Heels',
#  'Homemade',
#  'Housewife',
#  'Hungarian',
#  'Indian',
#  'Italian',
#  'Japanese',
#  'Jeans',
#  'Kitchen',
#  'Latina',
#  'Legs',
#  'Lingerie',
#  'MILF',
#  'Maid',
#  'Masturbation',
#  'Mature',
#  'Mexican',
#  'Mom',
#  'Natural Tits',
#  'Nipples',
#  'Non Nude',
#  'Nun',
#  'Nurse',
#  'Office',
#  'Oiled',
#  'PAWG',
#  'Pale',
#  'Panties',
#  'Pantyhose',
#  'Petite',
#  'Pigtails',
#  'Police',
#  'Polish',
#  'Public',
#  'Pussy',
#  'Redhead',
#  'Russian',
#  'Saggy Tits',
#  'Secretary',
#  'Selfie',
#  'Shaved',
#  'Short Hair',
#  'Shorts',
#  'Shower',
#  'Skinny',
#  'Skirt',
#  'Smoking',
#  'Socks',
#  'Solo',
#  'Spanish',
#  'Sports',
#  'Spreading',
#  'Stockings',
#  'Tall',
#  'Tattoo',
#  'Teacher',
#  'Thick',
#  'Thong',
#  'Tiny Tits',
#  'Ukrainian',
#  'Undressing',
#  'Uniform',
#  'Upskirt',
#  'Venezuela',
#  'White',
#  'Wife',
#  'Yoga',
#  'Yoga Pants']

# %%
len(all_tags)
# Out:
# 113

# %%
negative_aged_df.head()
# Out:
#    category                                       gallery_name  \
# 0  non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 1  non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 2  non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 3  non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
# 4  non-nude  curvy-36yo-czech-luciana-strips-and-teases-wit...
#
#           channel     models  \
# 0  Only All Sites  [Luciana]
# 1  Only All Sites  [Luciana]
# 2  Only All Sites  [Luciana]
# 3  Only All Sites  [Luciana]
# 4  Only All Sites  [Luciana]
#
#                                           categories  \
# 0  [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 1  [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 2  [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 3  [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
# 4  [Saggy Tits, Non Nude, Big Tits, Pantyhose, MI...
#
#                                            tags_list rating   views  \
# 0  [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 1  [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 2  [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 3  [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
# 4  [Big Natural Tits, Pantyhose, Big Saggy Tits, ...   100%  51,271
#
#                 filename  width  height
# 0  57352172_127_33ed.jpg   1280     853
# 1  57352172_022_99c3.jpg   1280     853
# 2  57352172_075_dc2a.jpg   1280     853
# 3  57352172_120_8cac.jpg   1280     853
# 4  57352172_080_1f1f.jpg   1280     853

# %%
export_dir = "/Users/milosz.bertman/Desktop/export"
for i, row in negative_aged_df.iterrows():
    file_path = SRC_DIR / row.category / row.gallery_name / row.filename
    # copy file path to export dir
# Out:
# /Volumes/external_drive/non-nude/curvy-36yo-czech-luciana-strips-and-teases-with-her-huge-covered-breasts-57352172/57352172_127_33ed.jpg

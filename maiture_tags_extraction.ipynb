# %%
import os
import re
import ast
import numpy as np
import pandas as pd
from pathlib import Path
import concurrent.futures

SRC_DIR = Path('/Volumes/external_drive')

# %%
df = pd.read_csv('image_high_res.csv')
df = df[df['tags_list'].notnull()]
df = df[df['categories'].notnull()]

# %%
df['models'] = df['models'].apply(ast.literal_eval)
df['categories'] = df['categories'].apply(ast.literal_eval)
df['tags_list'] = df['tags_list'].apply(ast.literal_eval)

# %%
age_tags = [
    'Mature',
    'Granny',
    'MILF',
    'Cougar',
]
physical_look_tags = [
    'Chubby',
    'BBW',
    'Clothed',
    'Curvy',
    'Natural Tits',
    'Saggy Tits',
    'Thick',
]
utility_tags = [
    'Bath',
    'Beach',
    'Christmas',
    'Glasses',
    'Gym',
    'Masturbation',
    'Non Nude',
    'Nun',
    'Nurse',
    'Office',
    'Panties',
    'Dress',
    'Pantyhose',
    'Police',
    'Pool',
    'Secretary',
    'Uniform',
    'Upskirt',
    'Sports',
    'Stockings',
    'Undressing',
    'Amateur',
    'Homemade',
    'Housewife',
    'Solo',
    'Selfie',
    'Vintage'
]
negative_tags = [
    'AI',
    'Anal',
    'Anal Gape',
    'Ass Fucking',
    'Ass Licking',
    'BBC',
    'BDSM',
    'Babe',
    'Babysitter',
    'Ball Licking',
    'Ballerina',
    'Beautiful',
    'Big Clit',
    'Big Cock',
    'Bisexual',
    'Blindfold',
    'Blowbang',
    'Blowjob',
    'Bodysuit',
    'Bondage',
    'Braces',
    'Bukkake',
    'CFNM',
    'Casting',
    'Caught',
    'Cheating',
    'Cheerleader',
    'Close Up',
    'College',
    'Cosplay',
    'Couple',
    'Cowgirl',
    'Creampie',
    'Cuckold',
    'Cum In Mouth',
    'Cum In Pussy',
    'Cum Swapping',
    'Cumshot',
    'Deepthroat',
    'Dildo',
    'Doctor',
    'Doggy Style',
    'Double Penetration',
    'Emo',
    'Erotic',
    'FFM',
    'Facesitting',
    'Facial',
    'Family',
    'Femdom',
    'Fingering',
    'Fisting',
    'Footjob',
    'Gangbang',
    'Girlfriend',
    'Glamour',
    'Gloryhole',
    'Granny',
    'Groupsex',
    'Gyno',
    'Hairy',
    'Handjob',
    'Hardcore',
    'Hentai',
    'Humping',
    'Interracial',
    'Kissing',
    'Ladyboy',
    'Latex',
    'Leather',
    'Lesbian',
    'MMF',
    'Massage',
    'Missionary',
    'Model',
    'Old Man',
    'Old Young',
    'Orgasm',
    'Orgy',
    'Outdoor',
    'POV',
    'Party',
    'Pegging',
    'Piercing',
    'Pinay',
    'Pissing',
    'Pool',
    'Pornstar',
    'Pregnant',
    'Pretty',
    'Prison',
    'Pussy Licking',
    'Reality',
    'SS',
    'Sandals',
    'Schoolgirl',
    'Seduction',
    'Sex Doll',
    'Sexy',
    'Shemale',
    'Small Cock',
    'Spanking',
    'Squirting',
    'Step Brother',
    'Step Sister',
    'Stepmom',
    'Strapon',
    'Stripper',
    'Swingers',
    'Teen',
    'Thai',
    'Threesome',
    'Titjob',
    'Tribbing',
    'Twink',
    'Twins',
    'Underwater',
    'Voyeur',
    'Wedding',
    'Wet'
]
negative_tags
# Out:
# ['AI',
#  'Anal',
#  'Anal Gape',
#  'Ass Fucking',
#  'Ass Licking',
#  'BBC',
#  'BDSM',
#  'Babe',
#  'Babysitter',
#  'Ball Licking',
#  'Ballerina',
#  'Beautiful',
#  'Big Clit',
#  'Big Cock',
#  'Bisexual',
#  'Blindfold',
#  'Blowbang',
#  'Blowjob',
#  'Bodysuit',
#  'Bondage',
#  'Braces',
#  'Bukkake',
#  'CFNM',
#  'Casting',
#  'Caught',
#  'Cheating',
#  'Cheerleader',
#  'Close Up',
#  'College',
#  'Cosplay',
#  'Couple',
#  'Cowgirl',
#  'Creampie',
#  'Cuckold',
#  'Cum In Mouth',
#  'Cum In Pussy',
#  'Cum Swapping',
#  'Cumshot',
#  'Deepthroat',
#  'Dildo',
#  'Doctor',
#  'Doggy Style',
#  'Double Penetration',
#  'Emo',
#  'Erotic',
#  'FFM',
#  'Facesitting',
#  'Facial',
#  'Family',
#  'Femdom',
#  'Fingering',
#  'Fisting',
#  'Footjob',
#  'Gangbang',
#  'Girlfriend',
#  'Glamour',
#  'Gloryhole',
#  'Granny',
#  'Groupsex',
#  'Gyno',
#  'Hairy',
#  'Handjob',
#  'Hardcore',
#  'Hentai',
#  'Humping',
#  'Interracial',
#  'Kissing',
#  'Ladyboy',
#  'Latex',
#  'Leather',
#  'Lesbian',
#  'MMF',
#  'Massage',
#  'Missionary',
#  'Model',
#  'Old Man',
#  'Old Young',
#  'Orgasm',
#  'Orgy',
#  'Outdoor',
#  'POV',
#  'Party',
#  'Pegging',
#  'Piercing',
#  'Pinay',
#  'Pissing',
#  'Pool',
#  'Pornstar',
#  'Pregnant',
#  'Pretty',
#  'Prison',
#  'Pussy Licking',
#  'Reality',
#  'SS',
#  'Sandals',
#  'Schoolgirl',
#  'Seduction',
#  'Sex Doll',
#  'Sexy',
#  'Shemale',
#  'Small Cock',
#  'Spanking',
#  'Squirting',
#  'Step Brother',
#  'Step Sister',
#  'Stepmom',
#  'Strapon',
#  'Stripper',
#  'Swingers',
#  'Teen',
#  'Thai',
#  'Threesome',
#  'Titjob',
#  'Tribbing',
#  'Twink',
#  'Twins',
#  'Underwater',
#  'Voyeur',
#  'Wedding',
#  'Wet']

# %%
aged_df = df[df['categories'].apply(lambda x: any(category in age_tags for category in x))]
looks_df = aged_df[aged_df['categories'].apply(lambda x: any(category in physical_look_tags for category in x))]
utility_df = looks_df[looks_df['categories'].apply(lambda x: any(category in utility_tags for category in x))]
negative_aged_df = utility_df[
    utility_df['categories'].apply(lambda x: all(category not in negative_tags for category in x))]
negative_aged_df = negative_aged_df.reset_index(drop=True)

# %%
negative_aged_df.shape
# Out:
# (28655, 11)

# %%
negative_aged_df.head()
# Out:
#   category                                       gallery_name channel  \
# 0    thong  mature-housewife-sasha-sweetman-parts-her-pink...  Karups
# 1    thong  mature-housewife-sasha-sweetman-parts-her-pink...  Karups
# 2    thong  mature-housewife-sasha-sweetman-parts-her-pink...  Karups
# 3    thong  mature-housewife-sasha-sweetman-parts-her-pink...  Karups
# 4    thong  mature-housewife-sasha-sweetman-parts-her-pink...  Karups
#
#              models                                         categories  \
# 0  [Sasha Sweetman]  [Housewife, Mature, Thong, Amateur, Saggy Tits...
# 1  [Sasha Sweetman]  [Housewife, Mature, Thong, Amateur, Saggy Tits...
# 2  [Sasha Sweetman]  [Housewife, Mature, Thong, Amateur, Saggy Tits...
# 3  [Sasha Sweetman]  [Housewife, Mature, Thong, Amateur, Saggy Tits...
# 4  [Sasha Sweetman]  [Housewife, Mature, Thong, Amateur, Saggy Tits...
#
#                                            tags_list rating   views  \
# 0  [Mature Spreading, Mature Saggy Tits, Big Ass ...   100%  17,323
# 1  [Mature Spreading, Mature Saggy Tits, Big Ass ...   100%  17,323
# 2  [Mature Spreading, Mature Saggy Tits, Big Ass ...   100%  17,323
# 3  [Mature Spreading, Mature Saggy Tits, Big Ass ...   100%  17,323
# 4  [Mature Spreading, Mature Saggy Tits, Big Ass ...   100%  17,323
#
#                 filename  width  height
# 0  56762812_003_b485.jpg   1280     853
# 1  56762812_001_3c17.jpg   1280     853
# 2  56762812_009_6531.jpg   1280     853
# 3  56762812_006_ae0f.jpg    853    1280
# 4  56762812_002_4150.jpg   1280     853

# %%
all_tags = sorted(list(set([item for sublist in negative_aged_df['categories'] for item in sublist])))


def clean_list(lst):
    lst = [re.sub(r'\s+', ' ', item) for item in lst]
    return list(set([item for item in lst if item != '']))


all_tags = clean_list(all_tags)
all_tags = sorted(list(clean_list(all_tags)))
all_tags
# Out:
# ['African',
#  'Amateur',
#  'Arab',
#  'Armpit',
#  'Asian',
#  'Ass',
#  'Asshole',
#  'Australian',
#  'BBW',
#  'Bath',
#  'Beach',
#  'Big Tits',
#  'Bikini',
#  'Blonde',
#  'Boots',
#  'Brazilian',
#  'British',
#  'Brunette',
#  'Cameltoe',
#  'Canadian',
#  'Centerfold',
#  'Christmas',
#  'Chubby',
#  'Clothed',
#  'Colombian',
#  'Cougar',
#  'Cuban',
#  'Curly',
#  'Curvy',
#  'Cute',
#  'Czech',
#  'Dress',
#  'Dutch',
#  'Ebony',
#  'European',
#  'Face',
#  'Fake Tits',
#  'Farm',
#  'Feet',
#  'Fetish',
#  'Flexible',
#  'French',
#  'German',
#  'Glasses',
#  'Gym',
#  'High Heels',
#  'Homemade',
#  'Housewife',
#  'Hungarian',
#  'Indian',
#  'Italian',
#  'Japanese',
#  'Jeans',
#  'Kitchen',
#  'Latina',
#  'Legs',
#  'Lingerie',
#  'MILF',
#  'Maid',
#  'Masturbation',
#  'Mature',
#  'Mexican',
#  'Mom',
#  'Natural Tits',
#  'Nipples',
#  'Non Nude',
#  'Nun',
#  'Nurse',
#  'Office',
#  'Oiled',
#  'PAWG',
#  'Pale',
#  'Panties',
#  'Pantyhose',
#  'Petite',
#  'Pigtails',
#  'Police',
#  'Polish',
#  'Public',
#  'Pussy',
#  'Redhead',
#  'Russian',
#  'Saggy Tits',
#  'Secretary',
#  'Selfie',
#  'Shaved',
#  'Short Hair',
#  'Shorts',
#  'Shower',
#  'Skinny',
#  'Skirt',
#  'Smoking',
#  'Socks',
#  'Solo',
#  'Spanish',
#  'Sports',
#  'Spreading',
#  'Stockings',
#  'Tall',
#  'Tattoo',
#  'Teacher',
#  'Thick',
#  'Thong',
#  'Tiny Tits',
#  'Ukrainian',
#  'Undressing',
#  'Uniform',
#  'Upskirt',
#  'Venezuela',
#  'White',
#  'Wife',
#  'Yoga',
#  'Yoga Pants']

# %%
len(all_tags)
# Out:
# 113

# %%
import random
from PIL import Image

random_image = random.randint(0, negative_aged_df.shape[0])
row = negative_aged_df.iloc[random_image]
path = SRC_DIR / row.category / row.gallery_name / row.filename
print(path)
image = Image.open(path)
image.show()
# Out:
# /Volumes/external_drive/undressing/all-over-30-performed-by-ana-b-naked-pics-48162078/48162078_012_24bb.jpg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 8
#       6 path = SRC_DIR / row.category / row.gallery_name / row.filename
#       7 print(path)
# ----> 8 image = Image.open(path)
#       9 image.show()
#
# File ~/Projects/milfusion/venv/lib/python3.12/site-packages/PIL/Image.py:3277, in open(fp, mode, formats)
#    3274     filename = os.path.realpath(os.fspath(fp))
#    3276 if filename:
# -> 3277     fp = builtins.open(filename, "rb")
#    3278     exclusive_fp = True
#    3280 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/external_drive/undressing/all-over-30-performed-by-ana-b-naked-pics-48162078/48162078_012_24bb.jpg'
